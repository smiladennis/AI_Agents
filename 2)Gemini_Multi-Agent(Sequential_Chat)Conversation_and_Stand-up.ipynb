# %% [markdown]
# ## Setup

# %%
#from utils import get_openai_api_key
#OPENAI_API_KEY = get_openai_api_key()
#print(OPENAI_API_KEY)

llm_config = {"model": "gemini-3.5-flash","api_key":"","api_type":"google"}

# %% [markdown]
# ## Define an AutoGen agent

# %%
from autogen import ConversableAgent

agent = ConversableAgent(
    name="chatbot",
    llm_config=llm_config,
    human_input_mode="NEVER",
)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\autogen\oai\gemini.py:65: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# Patching name='__init__', member=<function BedrockClient.__init__ at 0x000001E2FA1253A0>, patched=<function function.__call__ at 0x000001E2FA1254E0>
# Patching name='_retries', member=5, patched=5
# Patching name='cost', member=<function BedrockClient.cost at 0x000001E2FA125760>, patched=<function function.__call__ at 0x000001E2FA1259E0>
# Patching name='create', member=<function BedrockClient.create at 0x000001E2FA1256C0>, patched=<function function.__call__ at 0x000001E2FA125A80>
# Patching name='get_usage', member=<function BedrockClient.get_usage at 0x000001E2FA125800>, patched=<function function.__call__ at 0x000001E2FA125B20>
# Patching name='message_retrieval', member=<function BedrockClient.message_retrieval at 0x000001E2FA125440>, patched=<function function.__call__ at 0x000001E2FA125BC0>
# Patching name='parse_custom_params', member=<function BedrockClient.parse_custom_params at 0x000001E2FA125580>, patched=<function function.__call__ at 0x000001E2FA125C60>
# Patching name='parse_params', member=<function BedrockClient.parse_params at 0x000001E2FA125620>, patched=<function function.__call__ at 0x000001E2FA125D00>
# Patching name='__init__', member=<function LLMLingua.__init__ at 0x000001E2FF5720C0>, patched=<function function.__call__ at 0x000001E2FF571F80>
# Patching name='compress_text', member=<function LLMLingua.compress_text at 0x000001E2FF572160>, patched=<function function.__call__ at 0x000001E2FF572340>

# %%
reply = agent.generate_reply(
    messages=[{"content": "Tell me a joke.", "role": "user"}]
)
print(reply)
# Out:
# {'content': "Here is one of my favorites:\n\nWhy did the scarecrow win an award?\n\n... Because he was **outstanding in his field!** 🌾\n\nHope that brought a smile to your face! Let me know if you'd like to hear another one.", 'refusal': None, 'role': 'assistant', 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': None}
# C:\Users\User\anaconda3\Lib\site-packages\autogen\oai\gemini.py:803: UserWarning: Cost calculation is not implemented for model gemini-3.5-flash. Cost will be calculated zero.
#   warnings.warn(

# %%
reply = agent.generate_reply(
    messages=[{"content": "Repeat the joke.", "role": "user"}]
)
print(reply)
# Out:
# {'content': "I would love to repeat the joke, but you haven't told me one yet! \n\nGo ahead and tell me your joke, and I will happily repeat it for you. Or, if you'd like, I can tell you one first!", 'refusal': None, 'role': 'assistant', 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': None}

# %% [markdown]
# ## Conversation
#
# Setting up a conversation between two agents, Cathy and Joe, where the memory of their interactions is retained.

# %%
cathy = ConversableAgent(
    name="cathy",
    system_message=
    "Your name is Cathy and you are a stand-up comedian.",
    llm_config=llm_config,
    human_input_mode="NEVER",
)

joe = ConversableAgent(
    name="joe",
    system_message=
    "Your name is Joe and you are a stand-up comedian. "
    "Start the next joke from the punchline of the previous joke.",
    llm_config=llm_config,
    human_input_mode="NEVER",
)

# %% [markdown]
# **Note**: You might get a slightly different response (set of jokes) than what is shown in the video

# %%
chat_result = joe.initiate_chat(
    recipient=cathy, 
    message="I'm Joe. Cathy, let's keep the jokes rolling.",
    max_turns=2,
)
# Out:
# joe (to cathy):
#
# I'm Joe. Cathy, let's keep the jokes rolling.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Joe! What’s up, buddy? Thanks for having me! I love an audience of one. It’s great. It’s like performing for my dad, except you’re actually looking at me and not asleep in a recliner with a half-empty beer resting on your chest.
#
# So, Joe, let’s get right into it.
#
# I’ve officially reached that age where my favorite part of the day is when plans get canceled. You know what I mean? You get that text that says, "Hey, I can't make it tonight," and you have to type back, "Oh no, what a bummer!" but in reality, you’re doing a silent victory dance in your sweatpants. I’ve started proactively making plans with people I dislike, just for the thrill of hoping they’ll flake on me. It’s a sickness, Joe.
#
# And can we talk about modern technology for a second? I bought a "smart" scale recently. Huge mistake. It connects to my phone via Bluetooth. Why does my phone need to know my weight? Now my phone is judging me. I opened my weather app this morning and it was like, "Sunny, high of 75... and maybe take the stairs today, Cathy." I don't need that kind of passive-aggressive energy from a piece of glass!
#
# What about you, Joe? Give me a topic. You want to talk about dating, grocery shopping, or the fact that the "Close Door" button in elevators is 100% a placebo just to make us feel powerful?
#
# Hit me, Joe! What's on your mind?
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
# ...just to make us feel powerful. Cathy, you hit the nail on the head.
#
# But you know what other placebo we use to feel powerful? The crosswalk button.
#
# We press it once, we see the little red hand, and then we press it *eighteen more times*. Like the first press was just a polite suggestion, but the tenth press is a threat. "Listen to me, metal pole, I have places to be. Turn that hand into a little white walking man or I will tear this intersection apart!"
#
# And then the light finally changes, and we walk across the street with this smug grin, thinking, *Yeah, I did that. I controlled the traffic. I am the Magneto of metropolitan infrastructure.* No, you didn't, Joe. The city timed this light back in 1998. You just stood on a corner aggressively assaulting a piece of metal.
#
# But Cathy, you mentioned dating, and honestly, that whole "feeling powerful" placebo applies there too.
#
# I’m on the dating apps right now, and talk about a placebo of control. Swiping is just us pretending we have options. "No... no... yes... no." We act like we're Roman emperors in the Colosseum deciding the fate of gladiators. "Your bio says you like hiking? *Thumbs down! To the lions with you!*"
#
# But the reality of modern dating is that I’m not an emperor. I’m a guy sitting on his couch in the dark, eating shredded cheese straight from the bag at 2:00 AM, hoping that some girl named Sarah—who lists "live, laugh, love" as her personality—will swipe right on my picture where I’m holding a fish I didn’t even catch. I don't even fish, Cathy! I panicked! I saw a fish on the ground and I picked it up to look outdoor-sy!
#
# And when you finally do get a match? The anxiety is real. You have to send that first message, which is the hardest piece of creative writing in human history. It’s harder than writing a master's thesis. You want to sound fun, but not desperate. Smart, but not intimidating.
#
# So you end up sending: "Hey."
#
# Two letters. It took me forty-five minutes of drafting in my Notes app, and I settled on "Hey." And then you spend the next three days staring at your phone, waiting for three bouncing dots to appear. Those three dots are the ultimate test of human endurance. I’ve aged years watching those dots appear and disappear. Just tell me you don't want to get tacos, Sarah! Don't tease me with the dots!
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Joe! *[clapping hands]* Oh my god, you are killing me! "The Magneto of metropolitan infrastructure." That is going in my set, Joe. I’m stealing it, and when I get famous, I’m going to buy you a better fish to hold in your pictures.
#
# But can we talk about the fish for a second? Why is it always a fish?! Every guy’s profile is him holding a wet, dying bass like it’s a newborn baby. What is the evolutionary psychology there? Are you trying to prove to me that if the electric grid fails, you can feed our village?
#
# Because let’s be real, Joe. If the apocalypse comes, you’re not wading into a lake. You just told me you eat shredded cheese out of the bag at 2:00 AM! If the world ends, you’re not catching trout, you're scavenging a CVS for sour cream and onion chips.
#
# And by the way, "I saw a fish on the ground and picked it up"? Joe, that’s not outdoor-sy, that’s a crime scene investigation! You didn't catch that fish, you're an accessory after the fact!
#
# And the shredded cheese thing—I felt that in my soul. Eating shredded cheese straight from the bag is the ultimate "I’ve given up on presentation" food. It’s a taco, but with all the joy and self-respect removed. You’re just standing in the glow of the refrigerator light, tilted at a 45-degree angle so the cheese doesn't fall on the floor, chewing like a raccoon that broke into a grocery store.
#
# But let’s get to the texting. The agony of the "Hey."
#
# You spent forty-five minutes on "Hey"?! Joe, as a woman, I have to tell you—we *know* when a guy has overthought a "Hey." Because if you just send "Hey," we think, *Oh, he's casual.* But if you send "Hey..." with the ellipsis? Now you're a Victorian ghost harboring a dark secret.
#
# And those three bouncing dots! They are the absolute worst. They are the texting equivalent of a horror movie jump scare. You’re watching them... *bounce, bounce, bounce...* and you’re thinking, *Okay, here it comes, she’s writing a paragraph, she loves my fish picture, we’re getting married!*
#
# And then the dots disappear.
#
# Nothing.
#
# For three hours.
#
# What happened, Sarah?! Did you get hit by a bus? Did you realize "live, laugh, love" was a lie? Or did you just start typing "I have a boyfriend" and then think, *No, let him suffer in the void*?
#
# It's brutal out there, Joe. It makes you long for the old days. Remember how our grandparents met? My grandpa walked up to my grandma at a soda fountain, said, "You have nice ankles, let's get married," and they were together for sixty years! No swiping, no fish pictures, no bouncing dots of doom. Just ankles and commitment.
#
# How did we get from "nice ankles" to "behold this carp I found on the pavement"? Where did we go wrong, Joe?
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Print some results
#
# You can print out:
#
# 1. Chat history
# 2. Cost
# 3. Summary of the conversation

# %%
import pprint

pprint.pprint(chat_result.chat_history)
# Out:
# [{'content': "I'm Joe. Cathy, let's keep the jokes rolling.",
#   'name': 'joe',
#   'role': 'assistant'},
#  {'content': 'Joe! What’s up, buddy? Thanks for having me! I love an audience '
#              'of one. It’s great. It’s like performing for my dad, except '
#              'you’re actually looking at me and not asleep in a recliner with '
#              'a half-empty beer resting on your chest. \n'
#              '\n'
#              'So, Joe, let’s get right into it. \n'
#              '\n'
#              'I’ve officially reached that age where my favorite part of the '
#              'day is when plans get canceled. You know what I mean? You get '
#              'that text that says, "Hey, I can\'t make it tonight," and you '
#              'have to type back, "Oh no, what a bummer!" but in reality, '
#              'you’re doing a silent victory dance in your sweatpants. I’ve '
#              'started proactively making plans with people I dislike, just for '
#              'the thrill of hoping they’ll flake on me. It’s a sickness, Joe.\n'
#              '\n'
#              'And can we talk about modern technology for a second? I bought a '
#              '"smart" scale recently. Huge mistake. It connects to my phone '
#              'via Bluetooth. Why does my phone need to know my weight? Now my '
#              'phone is judging me. I opened my weather app this morning and it '
#              'was like, "Sunny, high of 75... and maybe take the stairs today, '
#              'Cathy." I don\'t need that kind of passive-aggressive energy '
#              'from a piece of glass!\n'
#              '\n'
#              'What about you, Joe? Give me a topic. You want to talk about '
#              'dating, grocery shopping, or the fact that the "Close Door" '
#              'button in elevators is 100% a placebo just to make us feel '
#              'powerful? \n'
#              '\n'
#              "Hit me, Joe! What's on your mind?",
#   'name': 'cathy',
#   'role': 'user'},
#  {'content': '...just to make us feel powerful. Cathy, you hit the nail on the '
#              'head. \n'
#              '\n'
#              'But you know what other placebo we use to feel powerful? The '
#              'crosswalk button. \n'
#              '\n'
#              'We press it once, we see the little red hand, and then we press '
#              'it *eighteen more times*. Like the first press was just a polite '
#              'suggestion, but the tenth press is a threat. "Listen to me, '
#              'metal pole, I have places to be. Turn that hand into a little '
#              'white walking man or I will tear this intersection apart!" \n'
#              '\n'
#              'And then the light finally changes, and we walk across the '
#              'street with this smug grin, thinking, *Yeah, I did that. I '
#              'controlled the traffic. I am the Magneto of metropolitan '
#              "infrastructure.* No, you didn't, Joe. The city timed this light "
#              'back in 1998. You just stood on a corner aggressively assaulting '
#              'a piece of metal. \n'
#              '\n'
#              'But Cathy, you mentioned dating, and honestly, that whole '
#              '"feeling powerful" placebo applies there too. \n'
#              '\n'
#              'I’m on the dating apps right now, and talk about a placebo of '
#              'control. Swiping is just us pretending we have options. "No... '
#              'no... yes... no." We act like we\'re Roman emperors in the '
#              'Colosseum deciding the fate of gladiators. "Your bio says you '
#              'like hiking? *Thumbs down! To the lions with you!*" \n'
#              '\n'
#              'But the reality of modern dating is that I’m not an emperor. I’m '
#              'a guy sitting on his couch in the dark, eating shredded cheese '
#              'straight from the bag at 2:00 AM, hoping that some girl named '
#              'Sarah—who lists "live, laugh, love" as her personality—will '
#              'swipe right on my picture where I’m holding a fish I didn’t even '
#              "catch. I don't even fish, Cathy! I panicked! I saw a fish on the "
#              'ground and I picked it up to look outdoor-sy! \n'
#              '\n'
#              'And when you finally do get a match? The anxiety is real. You '
#              'have to send that first message, which is the hardest piece of '
#              'creative writing in human history. It’s harder than writing a '
#              "master's thesis. You want to sound fun, but not desperate. "
#              'Smart, but not intimidating. \n'
#              '\n'
#              'So you end up sending: "Hey." \n'
#              '\n'
#              'Two letters. It took me forty-five minutes of drafting in my '
#              'Notes app, and I settled on "Hey." And then you spend the next '
#              'three days staring at your phone, waiting for three bouncing '
#              'dots to appear. Those three dots are the ultimate test of human '
#              'endurance. I’ve aged years watching those dots appear and '
#              "disappear. Just tell me you don't want to get tacos, Sarah! "
#              "Don't tease me with the dots!",
#   'name': 'joe',
#   'role': 'assistant'},
#  {'content': 'Joe! *[clapping hands]* Oh my god, you are killing me! "The '
#              'Magneto of metropolitan infrastructure." That is going in my '
#              'set, Joe. I’m stealing it, and when I get famous, I’m going to '
#              'buy you a better fish to hold in your pictures. \n'
#              '\n'
#              'But can we talk about the fish for a second? Why is it always a '
#              'fish?! Every guy’s profile is him holding a wet, dying bass like '
#              'it’s a newborn baby. What is the evolutionary psychology there? '
#              'Are you trying to prove to me that if the electric grid fails, '
#              'you can feed our village? \n'
#              '\n'
#              'Because let’s be real, Joe. If the apocalypse comes, you’re not '
#              'wading into a lake. You just told me you eat shredded cheese out '
#              'of the bag at 2:00 AM! If the world ends, you’re not catching '
#              "trout, you're scavenging a CVS for sour cream and onion chips. \n"
#              '\n'
#              'And by the way, "I saw a fish on the ground and picked it up"? '
#              'Joe, that’s not outdoor-sy, that’s a crime scene investigation! '
#              "You didn't catch that fish, you're an accessory after the fact!\n"
#              '\n'
#              'And the shredded cheese thing—I felt that in my soul. Eating '
#              'shredded cheese straight from the bag is the ultimate "I’ve '
#              'given up on presentation" food. It’s a taco, but with all the '
#              'joy and self-respect removed. You’re just standing in the glow '
#              'of the refrigerator light, tilted at a 45-degree angle so the '
#              "cheese doesn't fall on the floor, chewing like a raccoon that "
#              'broke into a grocery store. \n'
#              '\n'
#              'But let’s get to the texting. The agony of the "Hey." \n'
#              '\n'
#              'You spent forty-five minutes on "Hey"?! Joe, as a woman, I have '
#              'to tell you—we *know* when a guy has overthought a "Hey." '
#              'Because if you just send "Hey," we think, *Oh, he\'s casual.* '
#              'But if you send "Hey..." with the ellipsis? Now you\'re a '
#              'Victorian ghost harboring a dark secret. \n'
#              '\n'
#              'And those three bouncing dots! They are the absolute worst. They '
#              'are the texting equivalent of a horror movie jump scare. You’re '
#              'watching them... *bounce, bounce, bounce...* and you’re '
#              'thinking, *Okay, here it comes, she’s writing a paragraph, she '
#              'loves my fish picture, we’re getting married!* \n'
#              '\n'
#              'And then the dots disappear. \n'
#              '\n'
#              'Nothing. \n'
#              '\n'
#              'For three hours. \n'
#              '\n'
#              'What happened, Sarah?! Did you get hit by a bus? Did you realize '
#              '"live, laugh, love" was a lie? Or did you just start typing "I '
#              'have a boyfriend" and then think, *No, let him suffer in the '
#              'void*?\n'
#              '\n'
#              "It's brutal out there, Joe. It makes you long for the old days. "
#              'Remember how our grandparents met? My grandpa walked up to my '
#              'grandma at a soda fountain, said, "You have nice ankles, let\'s '
#              'get married," and they were together for sixty years! No '
#              'swiping, no fish pictures, no bouncing dots of doom. Just ankles '
#              'and commitment.\n'
#              '\n'
#              'How did we get from "nice ankles" to "behold this carp I found '
#              'on the pavement"? Where did we go wrong, Joe?',
#   'name': 'cathy',
#   'role': 'user'}]

# %%
pprint.pprint(chat_result.cost)
# Out:
# {'usage_excluding_cached_inference': {'gemini-3.5-flash': {'completion_tokens': 1624,
#                                                            'cost': 0,
#                                                            'prompt_tokens': 1372,
#                                                            'total_tokens': 2996},
#                                       'total_cost': 0},
#  'usage_including_cached_inference': {'gemini-3.5-flash': {'completion_tokens': 1624,
#                                                            'cost': 0,
#                                                            'prompt_tokens': 1372,
#                                                            'total_tokens': 2996},
#                                       'total_cost': 0}}

# %%
pprint.pprint(chat_result.summary)
# Out:
# ('Joe! *[clapping hands]* Oh my god, you are killing me! "The Magneto of '
#  'metropolitan infrastructure." That is going in my set, Joe. I’m stealing it, '
#  'and when I get famous, I’m going to buy you a better fish to hold in your '
#  'pictures. \n'
#  '\n'
#  'But can we talk about the fish for a second? Why is it always a fish?! Every '
#  'guy’s profile is him holding a wet, dying bass like it’s a newborn baby. '
#  'What is the evolutionary psychology there? Are you trying to prove to me '
#  'that if the electric grid fails, you can feed our village? \n'
#  '\n'
#  'Because let’s be real, Joe. If the apocalypse comes, you’re not wading into '
#  'a lake. You just told me you eat shredded cheese out of the bag at 2:00 AM! '
#  "If the world ends, you’re not catching trout, you're scavenging a CVS for "
#  'sour cream and onion chips. \n'
#  '\n'
#  'And by the way, "I saw a fish on the ground and picked it up"? Joe, that’s '
#  "not outdoor-sy, that’s a crime scene investigation! You didn't catch that "
#  "fish, you're an accessory after the fact!\n"
#  '\n'
#  'And the shredded cheese thing—I felt that in my soul. Eating shredded cheese '
#  'straight from the bag is the ultimate "I’ve given up on presentation" food. '
#  'It’s a taco, but with all the joy and self-respect removed. You’re just '
#  'standing in the glow of the refrigerator light, tilted at a 45-degree angle '
#  "so the cheese doesn't fall on the floor, chewing like a raccoon that broke "
#  'into a grocery store. \n'
#  '\n'
#  'But let’s get to the texting. The agony of the "Hey." \n'
#  '\n'
#  'You spent forty-five minutes on "Hey"?! Joe, as a woman, I have to tell '
#  'you—we *know* when a guy has overthought a "Hey." Because if you just send '
#  '"Hey," we think, *Oh, he\'s casual.* But if you send "Hey..." with the '
#  "ellipsis? Now you're a Victorian ghost harboring a dark secret. \n"
#  '\n'
#  'And those three bouncing dots! They are the absolute worst. They are the '
#  'texting equivalent of a horror movie jump scare. You’re watching them... '
#  '*bounce, bounce, bounce...* and you’re thinking, *Okay, here it comes, she’s '
#  'writing a paragraph, she loves my fish picture, we’re getting married!* \n'
#  '\n'
#  'And then the dots disappear. \n'
#  '\n'
#  'Nothing. \n'
#  '\n'
#  'For three hours. \n'
#  '\n'
#  'What happened, Sarah?! Did you get hit by a bus? Did you realize "live, '
#  'laugh, love" was a lie? Or did you just start typing "I have a boyfriend" '
#  'and then think, *No, let him suffer in the void*?\n'
#  '\n'
#  "It's brutal out there, Joe. It makes you long for the old days. Remember how "
#  'our grandparents met? My grandpa walked up to my grandma at a soda fountain, '
#  'said, "You have nice ankles, let\'s get married," and they were together for '
#  'sixty years! No swiping, no fish pictures, no bouncing dots of doom. Just '
#  'ankles and commitment.\n'
#  '\n'
#  'How did we get from "nice ankles" to "behold this carp I found on the '
#  'pavement"? Where did we go wrong, Joe?')

# %% [markdown]
# ## Get a better summary of the conversation

# %%
chat_result = joe.initiate_chat(
    cathy, 
    message="I'm Joe. Cathy, let's keep the jokes rolling.", 
    max_turns=2, 
    summary_method="reflection_with_llm", #predefined method
    summary_prompt="Summarize the conversation",
)
# Out:
# joe (to cathy):
#
# I'm Joe. Cathy, let's keep the jokes rolling.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Joe! What’s up, buddy? Thanks for having me! I love an audience of one. It’s great. It’s like performing for my dad, except you’re actually looking at me and not asleep in a recliner with a half-empty beer resting on your chest.
#
# So, Joe, let’s get right into it.
#
# I’ve officially reached that age where my favorite part of the day is when plans get canceled. You know what I mean? You get that text that says, "Hey, I can't make it tonight," and you have to type back, "Oh no, what a bummer!" but in reality, you’re doing a silent victory dance in your sweatpants. I’ve started proactively making plans with people I dislike, just for the thrill of hoping they’ll flake on me. It’s a sickness, Joe.
#
# But let’s get to the texting. The agony of the "Hey."
#
# You spent forty-five minutes on "Hey"?! Joe, as a woman, I have to tell you—we *know* when a guy has overthought a "Hey." Because if you just send "Hey," we think, *Oh, he's casual.* But if you send "Hey..." with the ellipsis? Now you're a Victorian ghost harboring a dark secret.
#
# And those three bouncing dots! They are the absolute worst. They are the texting equivalent of a horror movie jump scare. You’re watching them... *bounce, bounce, bounce...* and you’re thinking, *Okay, here it comes, she’s writing a paragraph, she loves my fish picture, we’re getting married!*
#
# And then the dots disappear.
#
# Nothing.
#
# For three hours.
#
# What happened, Sarah?! Did you get hit by a bus? Did you realize "live, laugh, love" was a lie? Or did you just start typing "I have a boyfriend" and then think, *No, let him suffer in the void*?
#
# It's brutal out there, Joe. It makes you long for the old days. Remember how our grandparents met? My grandpa walked up to my grandma at a soda fountain, said, "You have nice ankles, let's get married," and they were together for sixty years! No swiping, no fish pictures, no bouncing dots of doom. Just ankles and commitment.
#
# How did we get from "nice ankles" to "behold this carp I found on the pavement"? Where did we go wrong, Joe?
#
# --------------------------------------------------------------------------------

# %%
pprint.pprint(chat_result.summary)
# Out:
# {'annotations': None,
#  'audio': None,
#  'content': 'Modern life and dating are defined by an frustrating illusion of '
#             'control and self-imposed anxiety. From aggressively pressing '
#             'placebo crosswalk buttons to posing with scavenged fish on dating '
#             'apps and agonizing over the three bouncing dots of a text '
#             'message, people resort to absurd, overthought performances in a '
#             'desperate search for connection that was once far simpler.',
#  'function_call': None,
#  'refusal': None,
#  'role': 'assistant',
#  'tool_calls': None}

# %% [markdown]
# ## Chat Termination
#
# Chat can be terminated using a termination conditions.

# %%
cathy = ConversableAgent(
    name="cathy",
    system_message=
    "Your name is Cathy and you are a stand-up comedian. "
    "When you're ready to end the conversation, say 'I gotta go'.",
    llm_config=llm_config,
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: "I gotta go" in msg["content"],
)

joe = ConversableAgent(
    name="joe",
    system_message=
    "Your name is Joe and you are a stand-up comedian. "
    "When you're ready to end the conversation, say 'I gotta go'.",
    llm_config=llm_config,
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: "I gotta go" in msg["content"] or "Goodbye" in msg["content"],
)

# %%
chat_result = joe.initiate_chat(
    recipient=cathy,
    message="I'm Joe. Cathy, let's keep the jokes rolling."
)
# Out:
# joe (to cathy):
#
# I'm Joe. Cathy, let's keep the jokes rolling.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Hey Joe! Welcome to the front row. Bold move, usually people hide in the back so they don't get roasted. But I like you, you've got courage.
#
# So, Joe, I’ve been trying to make better life choices lately. I decided to start eating healthy. Do you know how hard that is? I went to the grocery store and bought kale. *Kale*. It tastes like anger, Joe. It’s the only vegetable that actively fights back while you chew it. I tried making those "kale chips" people talk about. You know what those are? They're just leaves that died in disappointment.
#
# And don't get me started on the gym. I finally went back last week. I stepped on the treadmill, and it asked me for my weight. I lied to a machine, Joe! I’m standing there looking around like, *“Is the treadmill going to tell the elliptical? Do they talk?”*
#
# What about you, Joe? You look like a guy who has his life together—or at least you're really good at pretending. What's your go-to excuse for skipping a workout?
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
